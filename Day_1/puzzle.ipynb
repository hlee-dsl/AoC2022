# %%
f = open('input.txt', 'rt')
line = 1;
current_sum = 0
elf_no = 1
the_elf = 1
second_elf = 1
third_elf = 1
max_cal = 0
second_cal = 0
third_cal = 0
for tx in f: 
    if tx.strip() == "": 
        print ("line:", line, "elf: ", elf_no, "cal: ", current_sum)
        if current_sum > max_cal:
            max_cal = current_sum
            the_elf = elf_no
            print ("Current choie: Elf ", the_elf, "Max Cal: ", max_cal)
        elif current_sum > second_cal:
            second_cal = current_sum
            second_elf = elf_no
            print ("second elf ", second_elf, "second cal: ", second_cal)
        elif current_sum > third_cal:
            third_cal = current_sum
            third_elf - elf_no
            print ("third elf :", third_elf, "third cal ", third_cal)

        elf_no += 1
        current_sum = 0
    else:
        current_sum += int(tx)
    line +=1

print ("Final: Elf ", the_elf, "has the max calories of ", max_cal)
total_cal = max_cal + second_cal + third_cal
print ("Total Cal from top three elfs: ", total_cal)
# Out:
# line: 7 elf:  1 cal:  36756
# Current choie: Elf  1 Max Cal:  36756
# line: 16 elf:  2 cal:  70369
# Current choie: Elf  2 Max Cal:  70369
# line: 24 elf:  3 cal:  46030
# second elf  3 second cal:  46030
# line: 39 elf:  4 cal:  55237
# second elf  4 second cal:  55237
# line: 52 elf:  5 cal:  49273
# third elf : 1 third cal  49273
# line: 57 elf:  6 cal:  61698
# second elf  6 second cal:  61698
# line: 68 elf:  7 cal:  41206
# line: 77 elf:  8 cal:  44233
# line: 80 elf:  9 cal:  56367
# third elf : 1 third cal  56367
# line: 88 elf:  10 cal:  44201
# line: 97 elf:  11 cal:  32018
# line: 104 elf:  12 cal:  37387
# line: 115 elf:  13 cal:  41580
# line: 120 elf:  14 cal:  49624
# line: 135 elf:  15 cal:  48434
# line: 137 elf:  16 cal:  30560
# line: 148 elf:  17 cal:  39161
# line: 161 elf:  18 cal:  46173
# line: 171 elf:  19 cal:  56296
# line: 182 elf:  20 cal:  35211
# line: 187 elf:  21 cal:  50095
# line: 191 elf:  22 cal:  58537
# third elf : 1 third cal  58537
# ...
